# %%
# 导入必要的库
import matplotlib as mpl
import matplotlib.pyplot as plt
# 在Jupyter notebook中内联显示图表
# %matplotlib inline  
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
from tqdm.auto import tqdm  # 进度条库
import torch
import torch.nn as nn
import torch.nn.functional as F

# 打印Python版本信息
print(sys.version_info)

# 打印各个库的版本信息
for module in mpl, np, pd, sklearn, torch:
    print(module.__name__, module.__version__)
    
# 设置设备：如果有GPU则使用GPU，否则使用CPU
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print(device)
# Out:
# sys.version_info(major=3, minor=12, micro=12, releaselevel='final', serial=0)
# matplotlib 3.10.8
# numpy 2.3.5
# pandas 3.0.0
# sklearn 1.8.0
# torch 2.10.0+cu130
# cuda:0

# %% [markdown]
# # 数据预处理

# %%
# 加载FashionMNIST数据集
from torchvision import datasets, transforms

# 定义数据预处理
transform = transforms.Compose([
    transforms.ToTensor(),  # 将PIL图像或numpy数组转换为tensor,ToTensor会自动将图像转换为tensor，并归一化到[0,1]范围
    # transforms.Normalize((0.5,), (0.5,))  # 标准化到[-1, 1]范围
])

# 下载并加载训练集
train_dataset = datasets.FashionMNIST(
    root='./data',  # 数据存储路径
    train=True,     # 加载训练集
    download=True,  # 如果数据不存在则下载
    transform=transform
)

# 下载并加载测试集
test_dataset = datasets.FashionMNIST(
    root='./data',
    train=False,    # 加载测试集
    download=True,
    transform=transform
)

# 打印数据集信息
print(f"训练集大小: {len(train_dataset)}")
print(f"测试集大小: {len(test_dataset)}")
print(f"训练集数据类型: {type(train_dataset)}")
print(f"单个dataset元素类型: {type(train_dataset[0])}")
print(f"单个dataset元素是什么: {train_dataset[0]}")
print(f"图像尺寸: {train_dataset[0][0].shape}")
# lables在这个路径https://github.com/zalandoresearch/fashion-mnist
# FashionMNIST类别标签
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
print(f"类别数量: {len(class_names)}")
print(f"类别标签: {class_names}")
# Out:
# 训练集大小: 60000
# 测试集大小: 10000
# 训练集数据类型: <class 'torchvision.datasets.mnist.FashionMNIST'>
# 单个dataset元素类型: <class 'tuple'>
# 单个dataset元素是什么: (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
#           0.2863, 0.0000, 0.0000, 0.0039, 0.0157, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0039, 0.0039, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000, 0.1412, 0.5333,
#           0.4980, 0.2431, 0.2118, 0.0000, 0.0000, 0.0000, 0.0039, 0.0118,
#           0.0157, 0.0000, 0.0000, 0.0118],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0235, 0.0000, 0.4000, 0.8000,
#           0.6902, 0.5255, 0.5647, 0.4824, 0.0902, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0471, 0.0392, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6078, 0.9255,
#           0.8118, 0.6980, 0.4196, 0.6118, 0.6314, 0.4275, 0.2510, 0.0902,
#           0.3020, 0.5098, 0.2824, 0.0588],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.2706, 0.8118, 0.8745,
#           0.8549, 0.8471, 0.8471, 0.6392, 0.4980, 0.4745, 0.4784, 0.5725,
#           0.5529, 0.3451, 0.6745, 0.2588],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0039, 0.0039, 0.0039, 0.0000, 0.7843, 0.9098, 0.9098,
#           0.9137, 0.8980, 0.8745, 0.8745, 0.8431, 0.8353, 0.6431, 0.4980,
#           0.4824, 0.7686, 0.8980, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7176, 0.8824, 0.8471,
#           0.8745, 0.8941, 0.9216, 0.8902, 0.8784, 0.8706, 0.8784, 0.8667,
#           0.8745, 0.9608, 0.6784, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7569, 0.8941, 0.8549,
#           0.8353, 0.7765, 0.7059, 0.8314, 0.8235, 0.8275, 0.8353, 0.8745,
#           0.8627, 0.9529, 0.7922, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0039, 0.0118, 0.0000, 0.0471, 0.8588, 0.8627, 0.8314,
#           0.8549, 0.7529, 0.6627, 0.8902, 0.8157, 0.8549, 0.8784, 0.8314,
#           0.8863, 0.7725, 0.8196, 0.2039],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0235, 0.0000, 0.3882, 0.9569, 0.8706, 0.8627,
#           0.8549, 0.7961, 0.7765, 0.8667, 0.8431, 0.8353, 0.8706, 0.8627,
#           0.9608, 0.4667, 0.6549, 0.2196],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0157, 0.0000, 0.0000, 0.2157, 0.9255, 0.8941, 0.9020,
#           0.8941, 0.9412, 0.9098, 0.8353, 0.8549, 0.8745, 0.9176, 0.8510,
#           0.8510, 0.8196, 0.3608, 0.0000],
#          [0.0000, 0.0000, 0.0039, 0.0157, 0.0235, 0.0275, 0.0078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.9294, 0.8863, 0.8510, 0.8745,
#           0.8706, 0.8588, 0.8706, 0.8667, 0.8471, 0.8745, 0.8980, 0.8431,
#           0.8549, 1.0000, 0.3020, 0.0000],
#          [0.0000, 0.0118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.2431, 0.5686, 0.8000, 0.8941, 0.8118, 0.8353, 0.8667,
#           0.8549, 0.8157, 0.8275, 0.8549, 0.8784, 0.8745, 0.8588, 0.8431,
#           0.8784, 0.9569, 0.6235, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.1725, 0.3216, 0.4196,
#           0.7412, 0.8941, 0.8627, 0.8706, 0.8510, 0.8863, 0.7843, 0.8039,
#           0.8275, 0.9020, 0.8784, 0.9176, 0.6902, 0.7373, 0.9804, 0.9725,
#           0.9137, 0.9333, 0.8431, 0.0000],
#          [0.0000, 0.2235, 0.7333, 0.8157, 0.8784, 0.8667, 0.8784, 0.8157,
#           0.8000, 0.8392, 0.8157, 0.8196, 0.7843, 0.6235, 0.9608, 0.7569,
#           0.8078, 0.8745, 1.0000, 1.0000, 0.8667, 0.9176, 0.8667, 0.8275,
#           0.8627, 0.9098, 0.9647, 0.0000],
#          [0.0118, 0.7922, 0.8941, 0.8784, 0.8667, 0.8275, 0.8275, 0.8392,
#           0.8039, 0.8039, 0.8039, 0.8627, 0.9412, 0.3137, 0.5882, 1.0000,
#           0.8980, 0.8667, 0.7373, 0.6039, 0.7490, 0.8235, 0.8000, 0.8196,
#           0.8706, 0.8941, 0.8824, 0.0000],
#          [0.3843, 0.9137, 0.7765, 0.8235, 0.8706, 0.8980, 0.8980, 0.9176,
#           0.9765, 0.8627, 0.7608, 0.8431, 0.8510, 0.9451, 0.2549, 0.2863,
#           0.4157, 0.4588, 0.6588, 0.8588, 0.8667, 0.8431, 0.8510, 0.8745,
#           0.8745, 0.8784, 0.8980, 0.1137],
#          [0.2941, 0.8000, 0.8314, 0.8000, 0.7569, 0.8039, 0.8275, 0.8824,
#           0.8471, 0.7255, 0.7725, 0.8078, 0.7765, 0.8353, 0.9412, 0.7647,
#           0.8902, 0.9608, 0.9373, 0.8745, 0.8549, 0.8314, 0.8196, 0.8706,
#           0.8627, 0.8667, 0.9020, 0.2627],
#          [0.1882, 0.7961, 0.7176, 0.7608, 0.8353, 0.7725, 0.7255, 0.7451,
#           0.7608, 0.7529, 0.7922, 0.8392, 0.8588, 0.8667, 0.8627, 0.9255,
#           0.8824, 0.8471, 0.7804, 0.8078, 0.7294, 0.7098, 0.6941, 0.6745,
#           0.7098, 0.8039, 0.8078, 0.4510],
#          [0.0000, 0.4784, 0.8588, 0.7569, 0.7020, 0.6706, 0.7176, 0.7686,
#           0.8000, 0.8235, 0.8353, 0.8118, 0.8275, 0.8235, 0.7843, 0.7686,
#           0.7608, 0.7490, 0.7647, 0.7490, 0.7765, 0.7529, 0.6902, 0.6118,
#           0.6549, 0.6941, 0.8235, 0.3608],
#          [0.0000, 0.0000, 0.2902, 0.7412, 0.8314, 0.7490, 0.6863, 0.6745,
#           0.6863, 0.7098, 0.7255, 0.7373, 0.7412, 0.7373, 0.7569, 0.7765,
#           0.8000, 0.8196, 0.8235, 0.8235, 0.8275, 0.7373, 0.7373, 0.7608,
#           0.7529, 0.8471, 0.6667, 0.0000],
#          [0.0078, 0.0000, 0.0000, 0.0000, 0.2588, 0.7843, 0.8706, 0.9294,
#           0.9373, 0.9490, 0.9647, 0.9529, 0.9569, 0.8667, 0.8627, 0.7569,
#           0.7490, 0.7020, 0.7137, 0.7137, 0.7098, 0.6902, 0.6510, 0.6588,
#           0.3882, 0.2275, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1569,
#           0.2392, 0.1725, 0.2824, 0.1608, 0.1373, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]]), 9)
# 图像尺寸: torch.Size([1, 28, 28])
# 类别数量: 10
# 类别标签: ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
print(train_dataset.classes)
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
import matplotlib.pyplot as plt

# 显示前15张图片，每行5张，共3行
fig, axes = plt.subplots(3, 5, figsize=(12, 8))
fig.suptitle('FashionMNIST Dataset - First 15 Images', fontsize=16)

for i in range(15):
    row = i // 5
    col = i % 5
    
    # 获取图像和标签
    image, label = train_dataset[i]
    
    # 将tensor转换为numpy数组并去掉通道维度
    image_np = image.squeeze().numpy()
    
    # 显示图像
    axes[row, col].imshow(image_np, cmap='gray')
    axes[row, col].set_title(f'{class_names[label]}')
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %%
from torch.utils.data import DataLoader

# 创建训练集和验证集的DataLoader
batch_size = 32

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,  # 训练时打乱数据
    num_workers=2  # 使用多进程加载数据
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,  # 测试时不需要打乱
    num_workers=2
)

print(f"训练集DataLoader批次数: {len(train_loader)}")
print(f"测试集DataLoader批次数: {len(test_loader)}")
print(f"每个批次大小: {batch_size}")

# 查看一个批次的数据
train_iter = iter(train_loader)
batch_images, batch_labels = next(train_iter)
print(f"批次图像张量形状: {batch_images.shape}")
print(f"批次标签张量形状: {batch_labels.shape}")
print(batch_labels)
# Out:
# 训练集DataLoader批次数: 1875
# 测试集DataLoader批次数: 313
# 每个批次大小: 32
# 批次图像张量形状: torch.Size([32, 1, 28, 28])
# 批次标签张量形状: torch.Size([32])
# tensor([5, 7, 2, 6, 9, 7, 0, 8, 9, 5, 4, 7, 5, 5, 5, 4, 3, 4, 1, 9, 2, 1, 5, 8,
#         9, 0, 6, 1, 8, 8, 3, 2])

# %%
28*28
# Out:
# 784

# %% [markdown]
# # 搭建模型

# %%
import torch.nn as nn

class FashionCNN(nn.Module):
    def __init__(self):
        super(FashionCNN, self).__init__()
        # 输入 (batch, 1, 28, 28)
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)   # (batch, 32, 28, 28)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)  # (batch, 32, 28, 28)
        self.pool = nn.MaxPool2d(2, 2)                           # (batch, 32, 14, 14)
        
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # (batch, 64, 14, 14)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, padding=1)  # (batch, 64, 14, 14)
        
        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, padding=1) # (batch, 128, 7, 7)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1) # (batch, 128, 7, 7)
        
        self.relu = nn.ReLU(inplace=True)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(128 * 3 * 3, 128)
        self.fc2 = nn.Linear(128, 10)
    
    def forward(self, x):
        x = self.relu(self.conv1(x))
        # print('After conv1+relu:', x.shape)
        x = self.relu(self.conv2(x))
        # print('After conv2+relu:', x.shape)
        x = self.pool(x)
        # print('After pool1:', x.shape)
        
        x = self.relu(self.conv3(x))
        # print('After conv3+relu:', x.shape)
        x = self.relu(self.conv4(x))
        # print('After conv4+relu:', x.shape)
        x = self.pool(x)
        # print('After pool2:', x.shape)
        
        x = self.relu(self.conv5(x))
        # print('After conv5+relu:', x.shape)
        x = self.relu(self.conv6(x))
        # print('After conv6+relu:', x.shape)
        x=self.pool(x)
        # print('After pool3:', x.shape)

        x = self.flatten(x)
        # print('After flatten:', x.shape)
        x = self.relu(self.fc1(x))
        # print('After fc1+relu:', x.shape)
        x = self.fc2(x)
        # print('After fc2:', x.shape)
        return x

# 实例化模型
model = FashionCNN()

# %%
# 使用随机输入对模型进行一次前向计算以验证模型结构是否正确
import torch

dummy_input = torch.randn(32, 1, 28, 28)  # batch_size=1, channels=1, height=28, width=28
output = model(dummy_input) #前向传播/前向计算/正向传播
print(f"Output shape: {output.shape}")
# Out:
# Output shape: torch.Size([32, 10])

# %%
# 输出model每一层的参数量
total_params = 0  # 初始化总参数量为0
print("各层参数量统计：")  # 打印参数统计表头
for name, param in model.named_parameters():  # 遍历模型中所有需要优化的参数
    if param.requires_grad:  # 只有需要梯度更新的参数才统计
        num_params = param.numel()  # 计算当前参数的元素总数
        total_params += num_params  # 更新总参数量
        print(f"{name}: {num_params}")  # 输出当前层的参数量
print(f"模型总参数量: {total_params}")  # 输出模型总参数量
# Out:
# 各层参数量统计：
# conv1.weight: 288
# conv1.bias: 32
# conv2.weight: 9216
# conv2.bias: 32
# conv3.weight: 18432
# conv3.bias: 64
# conv4.weight: 36864
# conv4.bias: 64
# conv5.weight: 73728
# conv5.bias: 128
# conv6.weight: 147456
# conv6.bias: 128
# fc1.weight: 147456
# fc1.bias: 128
# fc2.weight: 1280
# fc2.bias: 10
# 模型总参数量: 435306

# %% [markdown]
# # 训练

# %%
import torch.nn as nn
import torch.optim as optim

# 初始化交叉熵损失函数，内部会做softmax
criterion = nn.CrossEntropyLoss()

# 初始化优化器（这里选用Adam，也可以使用SGD等）
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import wangdao_train
# 假设train_loader和val_loader已定义，device已经设为"cuda"或"cpu"
trainer = wangdao_train.Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=test_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    eval_step=500
)

# 设定训练轮数
num_epochs = 20

# 开始训练
trainer.train(num_epochs)
# Out:
# [Step 500] Val Loss: 0.5388 Val Acc: 0.8134
# [Step 1000] Val Loss: 0.4067 Val Acc: 0.8458
# [Step 1500] Val Loss: 0.3718 Val Acc: 0.8653
# Epoch [1/20]  Train Loss: 0.4888  Train Acc: 0.8174
# [Step 2000] Val Loss: 0.3476 Val Acc: 0.8730
# [Step 2500] Val Loss: 0.3618 Val Acc: 0.8691
# [Step 3000] Val Loss: 0.2859 Val Acc: 0.8936
# [Step 3500] Val Loss: 0.2956 Val Acc: 0.8915
# Epoch [2/20]  Train Loss: 0.2974  Train Acc: 0.8900
# [Step 4000] Val Loss: 0.2936 Val Acc: 0.8899
# [Step 4500] Val Loss: 0.2925 Val Acc: 0.8892
# [Step 5000] Val Loss: 0.2866 Val Acc: 0.8930
# [Step 5500] Val Loss: 0.2493 Val Acc: 0.9070
# Epoch [3/20]  Train Loss: 0.2491  Train Acc: 0.9084
# [Step 6000] Val Loss: 0.2725 Val Acc: 0.8989
# [Step 6500] Val Loss: 0.2767 Val Acc: 0.8999
# [Step 7000] Val Loss: 0.2614 Val Acc: 0.9030
# [Step 7500] Val Loss: 0.2494 Val Acc: 0.9090
# Epoch [4/20]  Train Loss: 0.2173  Train Acc: 0.9195
# [Step 8000] Val Loss: 0.2613 Val Acc: 0.9076
# [Step 8500] Val Loss: 0.2644 Val Acc: 0.9053
# [Step 9000] Val Loss: 0.2474 Val Acc: 0.9146
# Epoch [5/20]  Train Loss: 0.1903  Train Acc: 0.9288
# [Step 9500] Val Loss: 0.2323 Val Acc: 0.9128
# [Step 10000] Val Loss: 0.2457 Val Acc: 0.9144
# [Step 10500] Val Loss: 0.2392 Val Acc: 0.9128
# [Step 11000] Val Loss: 0.2397 Val Acc: 0.9104
# Epoch [6/20]  Train Loss: 0.1713  Train Acc: 0.9354
# [Step 11500] Val Loss: 0.2413 Val Acc: 0.9123
# [Step 12000] Val Loss: 0.2362 Val Acc: 0.9152
# [Step 12500] Val Loss: 0.2477 Val Acc: 0.9125
# [Step 13000] Val Loss: 0.2472 Val Acc: 0.9166
# Epoch [7/20]  Train Loss: 0.1509  Train Acc: 0.9430
# [Step 13500] Val Loss: 0.2490 Val Acc: 0.9169
# [Step 14000] Val Loss: 0.2547 Val Acc: 0.9087
# [Step 14500] Val Loss: 0.2298 Val Acc: 0.9235
# [Step 15000] Val Loss: 0.2606 Val Acc: 0.9169
# Epoch [8/20]  Train Loss: 0.1349  Train Acc: 0.9489
# [Step 15500] Val Loss: 0.2468 Val Acc: 0.9205
# [Step 16000] Val Loss: 0.2742 Val Acc: 0.9114
# [Step 16500] Val Loss: 0.2548 Val Acc: 0.9205
# Epoch [9/20]  Train Loss: 0.1216  Train Acc: 0.9537
# [Step 17000] Val Loss: 0.2682 Val Acc: 0.9205
# [Step 17500] Val Loss: 0.2930 Val Acc: 0.9154
# [Step 18000] Val Loss: 0.2627 Val Acc: 0.9174
# [Step 18500] Val Loss: 0.2776 Val Acc: 0.9175
# Epoch [10/20]  Train Loss: 0.1106  Train Acc: 0.9580
# [Step 19000] Val Loss: 0.2762 Val Acc: 0.9229
# [Step 19500] Val Loss: 0.2871 Val Acc: 0.9166
# [Step 20000] Val Loss: 0.2652 Val Acc: 0.9223
# [Step 20500] Val Loss: 0.2892 Val Acc: 0.9208
# Epoch [11/20]  Train Loss: 0.0992  Train Acc: 0.9621
# [Step 21000] Val Loss: 0.3160 Val Acc: 0.9198
# [Step 21500] Val Loss: 0.3115 Val Acc: 0.9133
# [Step 22000] Val Loss: 0.2762 Val Acc: 0.9184
# [Step 22500] Val Loss: 0.2939 Val Acc: 0.9174
# Epoch [12/20]  Train Loss: 0.0900  Train Acc: 0.9666
# [Step 23000] Val Loss: 0.3258 Val Acc: 0.9195
# [Step 23500] Val Loss: 0.3132 Val Acc: 0.9162
# [Step 24000] Val Loss: 0.3399 Val Acc: 0.9154
# Epoch [13/20]  Train Loss: 0.0832  Train Acc: 0.9689
# [Step 24500] Val Loss: 0.3738 Val Acc: 0.9194
# [Step 25000] Val Loss: 0.3414 Val Acc: 0.9189
# [Step 25500] Val Loss: 0.3491 Val Acc: 0.9108
# [Step 26000] Val Loss: 0.3206 Val Acc: 0.9190
# Epoch [14/20]  Train Loss: 0.0802  Train Acc: 0.9701
# [Step 26500] Val Loss: 0.3635 Val Acc: 0.9165
# [Step 27000] Val Loss: 0.3476 Val Acc: 0.9137
# [Step 27500] Val Loss: 0.3436 Val Acc: 0.9140
# [Step 28000] Val Loss: 0.3734 Val Acc: 0.9126
# Epoch [15/20]  Train Loss: 0.0702  Train Acc: 0.9733
# [Step 28500] Val Loss: 0.3760 Val Acc: 0.9186
# [Step 29000] Val Loss: 0.3867 Val Acc: 0.9153
# [Step 29500] Val Loss: 0.3779 Val Acc: 0.9119
# [Step 30000] Val Loss: 0.3479 Val Acc: 0.9172
# Epoch [16/20]  Train Loss: 0.0672  Train Acc: 0.9746
# [Step 30500] Val Loss: 0.4329 Val Acc: 0.9127
# [Step 31000] Val Loss: 0.3809 Val Acc: 0.9181
# [Step 31500] Val Loss: 0.3694 Val Acc: 0.9187
# Epoch [17/20]  Train Loss: 0.0666  Train Acc: 0.9752
# [Step 32000] Val Loss: 0.4174 Val Acc: 0.9172
# [Step 32500] Val Loss: 0.3859 Val Acc: 0.9170
# [Step 33000] Val Loss: 0.3798 Val Acc: 0.9092
# [Step 33500] Val Loss: 0.4150 Val Acc: 0.9150
# Epoch [18/20]  Train Loss: 0.0610  Train Acc: 0.9779
# [Step 34000] Val Loss: 0.4355 Val Acc: 0.9184
# [Step 34500] Val Loss: 0.4393 Val Acc: 0.9140
# [Step 35000] Val Loss: 0.3830 Val Acc: 0.9184
# [Step 35500] Val Loss: 0.3565 Val Acc: 0.9177
# Epoch [19/20]  Train Loss: 0.0599  Train Acc: 0.9788
# [Step 36000] Val Loss: 0.4019 Val Acc: 0.9186
# [Step 36500] Val Loss: 0.3821 Val Acc: 0.9208
# [Step 37000] Val Loss: 0.4364 Val Acc: 0.9103
# [Step 37500] Val Loss: 0.3455 Val Acc: 0.9193
# Epoch [20/20]  Train Loss: 0.0593  Train Acc: 0.9788

# %%
trainer.plot_curves()
