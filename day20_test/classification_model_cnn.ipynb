# %%
# 导入必要的库
import matplotlib as mpl
import matplotlib.pyplot as plt
# 在Jupyter notebook中内联显示图表
# %matplotlib inline  
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
from tqdm.auto import tqdm  # 进度条库
import torch
import torch.nn as nn
import torch.nn.functional as F

# 打印Python版本信息
print(sys.version_info)

# 打印各个库的版本信息
for module in mpl, np, pd, sklearn, torch:
    print(module.__name__, module.__version__)
    
# 设置设备：如果有GPU则使用GPU，否则使用CPU
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print(device)
# Out:
# sys.version_info(major=3, minor=12, micro=12, releaselevel='final', serial=0)
# matplotlib 3.10.8
# numpy 2.3.5
# pandas 3.0.0
# sklearn 1.8.0
# torch 2.10.0+cu130
# cuda:0

# %% [markdown]
# # 数据预处理

# %%
# 加载FashionMNIST数据集
from torchvision import datasets, transforms

# 1. 首先只使用 ToTensor() 来计算均值和标准差
temp_transform = transforms.Compose([
    transforms.ToTensor(),
])

temp_train_dataset = datasets.FashionMNIST(
    root='../day20/data',
    train=True,
    download=True,
    transform=temp_transform
)

# 计算均值和标准差
# dataset.data 的形状是 (60000, 28, 28)，且是 uint8 类型 [0, 255]
# 我们需要将其转换为 float32 并归一化到 [0, 1]
train_data = temp_train_dataset.data.type(torch.float32) / 255.0
mean = train_data.mean().item()
std = train_data.std().item()

print(f"计算得到的均值: {mean:.4f}")
print(f"计算得到的标准差: {std:.4f}")

# 2. 定义包含标准化的数据预处理
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((mean,), (std,))  # 使用计算出的均值和标准差
])

# 3. 使用最终的 transform 重新加载数据集
train_dataset = datasets.FashionMNIST(
    root='../day20/data',
    train=True,
    download=True,
    transform=transform
)

test_dataset = datasets.FashionMNIST(
    root='../day20/data',
    train=False,
    download=True,
    transform=transform
)

# 打印数据集信息
print(f"训练集大小: {len(train_dataset)}")
print(f"测试集大小: {len(test_dataset)}")
print(f"训练集数据类型: {type(train_dataset)}")
print(f"单个dataset元素类型: {type(train_dataset[0])}")
print(f"图像尺寸: {train_dataset[0][0].shape}")
# FashionMNIST类别标签
print(f"类别标签: {train_dataset.classes}")
# Out:
# 计算得到的均值: 0.2860
# 计算得到的标准差: 0.3530
# 训练集大小: 60000
# 测试集大小: 10000
# 训练集数据类型: <class 'torchvision.datasets.mnist.FashionMNIST'>
# 单个dataset元素类型: <class 'tuple'>
# 图像尺寸: torch.Size([1, 28, 28])
# 类别标签: ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
from torch.utils.data import DataLoader

# 创建训练集和验证集的DataLoader
batch_size = 32

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,  # 训练时打乱数据
    num_workers=2  # 使用多进程加载数据
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,  # 测试时不需要打乱
    num_workers=2
)

print(f"训练集DataLoader批次数: {len(train_loader)}")
print(f"测试集DataLoader批次数: {len(test_loader)}")
print(f"每个批次大小: {batch_size}")

# 查看一个批次的数据
train_iter = iter(train_loader)
batch_images, batch_labels = next(train_iter)
print(f"批次图像张量形状: {batch_images.shape}")
print(f"批次标签张量形状: {batch_labels.shape}")
print(batch_labels)
# Out:
# 训练集DataLoader批次数: 1875
# 测试集DataLoader批次数: 313
# 每个批次大小: 32
# 批次图像张量形状: torch.Size([32, 1, 28, 28])
# 批次标签张量形状: torch.Size([32])
# tensor([6, 8, 3, 5, 9, 1, 8, 2, 1, 5, 8, 5, 1, 8, 2, 8, 1, 5, 9, 3, 3, 9, 8, 8,
#         8, 6, 6, 8, 9, 2, 3, 9])

# %% [markdown]
# # 搭建模型

# %%
import torch.nn as nn

class FashionCNN(nn.Module):
    def __init__(self):
        super(FashionCNN, self).__init__()
        # 输入 (batch, 1, 28, 28)
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)   # (batch, 32, 28, 28)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)  # (batch, 32, 28, 28)
        self.pool = nn.MaxPool2d(2, 2)                           # (batch, 32, 14, 14)
        
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # (batch, 64, 14, 14)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, padding=1)  # (batch, 64, 14, 14)
        
        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, padding=1) # (batch, 128, 7, 7)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1) # (batch, 128, 7, 7)
        
        self.relu = nn.ReLU(inplace=True)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(128 * 3 * 3, 128)
        self.fc2 = nn.Linear(128, 10)
    
    def forward(self, x):
        x = self.relu(self.conv1(x))
        # print('After conv1+relu:', x.shape)
        x = self.relu(self.conv2(x))
        # print('After conv2+relu:', x.shape)
        x = self.pool(x)
        # print('After pool1:', x.shape)
        
        x = self.relu(self.conv3(x))
        # print('After conv3+relu:', x.shape)
        x = self.relu(self.conv4(x))
        # print('After conv4+relu:', x.shape)
        x = self.pool(x)
        # print('After pool2:', x.shape)
        
        x = self.relu(self.conv5(x))
        # print('After conv5+relu:', x.shape)
        x = self.relu(self.conv6(x))
        # print('After conv6+relu:', x.shape)
        x=self.pool(x)
        # print('After pool3:', x.shape)

        x = self.flatten(x)
        # print('After flatten:', x.shape)
        x = self.relu(self.fc1(x))
        # print('After fc1+relu:', x.shape)
        x = self.fc2(x)
        # print('After fc2:', x.shape)
        return x

# 实例化模型
model = FashionCNN()

# %%
# 使用随机输入对模型进行一次前向计算以验证模型结构是否正确
import torch

dummy_input = torch.randn(32, 1, 28, 28)  # batch_size=1, channels=1, height=28, width=28
output = model(dummy_input) #前向传播/前向计算/正向传播
print(f"Output shape: {output.shape}")
# Out:
# Output shape: torch.Size([32, 10])

# %%
# 输出model每一层的参数量
total_params = 0  # 初始化总参数量为0
print("各层参数量统计：")  # 打印参数统计表头
for name, param in model.named_parameters():  # 遍历模型中所有需要优化的参数
    if param.requires_grad:  # 只有需要梯度更新的参数才统计
        num_params = param.numel()  # 计算当前参数的元素总数
        total_params += num_params  # 更新总参数量
        print(f"{name}: {num_params}")  # 输出当前层的参数量
print(f"模型总参数量: {total_params}")  # 输出模型总参数量
# Out:
# 各层参数量统计：
# conv1.weight: 288
# conv1.bias: 32
# conv2.weight: 9216
# conv2.bias: 32
# conv3.weight: 18432
# conv3.bias: 64
# conv4.weight: 36864
# conv4.bias: 64
# conv5.weight: 73728
# conv5.bias: 128
# conv6.weight: 147456
# conv6.bias: 128
# fc1.weight: 147456
# fc1.bias: 128
# fc2.weight: 1280
# fc2.bias: 10
# 模型总参数量: 435306

# %% [markdown]
# # 训练

# %%
import torch.nn as nn
import torch.optim as optim

# 初始化交叉熵损失函数，内部会做softmax
criterion = nn.CrossEntropyLoss()

# 初始化优化器（这里选用Adam，也可以使用SGD等）
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import wangdao_train
# 假设train_loader和val_loader已定义，device已经设为"cuda"或"cpu"
trainer = wangdao_train.Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=test_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    eval_step=500
)

# 设定训练轮数
num_epochs = 20

# 开始训练
trainer.train(num_epochs)
# Out:
# [Step 500] Val Loss: 0.5005 Val Acc: 0.8203
# [Step 1000] Val Loss: 0.4179 Val Acc: 0.8487
# [Step 1500] Val Loss: 0.3367 Val Acc: 0.8765
# Epoch [1/20]  Train Loss: 0.4543  Train Acc: 0.8316
# [Step 2000] Val Loss: 0.3094 Val Acc: 0.8883
# [Step 2500] Val Loss: 0.2934 Val Acc: 0.8921
# [Step 3000] Val Loss: 0.2798 Val Acc: 0.9002
# [Step 3500] Val Loss: 0.2690 Val Acc: 0.9033
# Epoch [2/20]  Train Loss: 0.2673  Train Acc: 0.9023
# [Step 4000] Val Loss: 0.2597 Val Acc: 0.9055
# [Step 4500] Val Loss: 0.2446 Val Acc: 0.9117
# [Step 5000] Val Loss: 0.2486 Val Acc: 0.9094
# [Step 5500] Val Loss: 0.2502 Val Acc: 0.9098
# Epoch [3/20]  Train Loss: 0.2204  Train Acc: 0.9193
# [Step 6000] Val Loss: 0.2692 Val Acc: 0.9061
# [Step 6500] Val Loss: 0.2273 Val Acc: 0.9153
# [Step 7000] Val Loss: 0.2295 Val Acc: 0.9146
# [Step 7500] Val Loss: 0.2447 Val Acc: 0.9119
# Epoch [4/20]  Train Loss: 0.1894  Train Acc: 0.9304
# [Step 8000] Val Loss: 0.2879 Val Acc: 0.9125
# [Step 8500] Val Loss: 0.2380 Val Acc: 0.9150
# [Step 9000] Val Loss: 0.2257 Val Acc: 0.9215
# Epoch [5/20]  Train Loss: 0.1672  Train Acc: 0.9379
# [Step 9500] Val Loss: 0.2343 Val Acc: 0.9170
# [Step 10000] Val Loss: 0.2708 Val Acc: 0.9097
# [Step 10500] Val Loss: 0.2316 Val Acc: 0.9221
# [Step 11000] Val Loss: 0.2324 Val Acc: 0.9196
# Epoch [6/20]  Train Loss: 0.1461  Train Acc: 0.9468
# [Step 11500] Val Loss: 0.2710 Val Acc: 0.9200
# [Step 12000] Val Loss: 0.2614 Val Acc: 0.9189
# [Step 12500] Val Loss: 0.2235 Val Acc: 0.9227
# [Step 13000] Val Loss: 0.2430 Val Acc: 0.9213
# Epoch [7/20]  Train Loss: 0.1309  Train Acc: 0.9506
# [Step 13500] Val Loss: 0.2707 Val Acc: 0.9182
# [Step 14000] Val Loss: 0.2669 Val Acc: 0.9182
# [Step 14500] Val Loss: 0.2710 Val Acc: 0.9222
# [Step 15000] Val Loss: 0.2489 Val Acc: 0.9222
# Epoch [8/20]  Train Loss: 0.1170  Train Acc: 0.9564
# [Step 15500] Val Loss: 0.2633 Val Acc: 0.9193
# [Step 16000] Val Loss: 0.2757 Val Acc: 0.9202
# [Step 16500] Val Loss: 0.2826 Val Acc: 0.9111
# Epoch [9/20]  Train Loss: 0.1056  Train Acc: 0.9608
# [Step 17000] Val Loss: 0.2789 Val Acc: 0.9263
# [Step 17500] Val Loss: 0.2889 Val Acc: 0.9181
# [Step 18000] Val Loss: 0.2718 Val Acc: 0.9203
# [Step 18500] Val Loss: 0.2777 Val Acc: 0.9231
# Epoch [10/20]  Train Loss: 0.0952  Train Acc: 0.9650
# [Step 19000] Val Loss: 0.2834 Val Acc: 0.9268
# [Step 19500] Val Loss: 0.2935 Val Acc: 0.9221
# [Step 20000] Val Loss: 0.2899 Val Acc: 0.9196
# [Step 20500] Val Loss: 0.2953 Val Acc: 0.9179
# Epoch [11/20]  Train Loss: 0.0859  Train Acc: 0.9673
# [Step 21000] Val Loss: 0.3325 Val Acc: 0.9233
# [Step 21500] Val Loss: 0.2978 Val Acc: 0.9219
# [Step 22000] Val Loss: 0.3066 Val Acc: 0.9203
# [Step 22500] Val Loss: 0.3181 Val Acc: 0.9216
# Epoch [12/20]  Train Loss: 0.0809  Train Acc: 0.9699
# [Step 23000] Val Loss: 0.3194 Val Acc: 0.9207
# [Step 23500] Val Loss: 0.3078 Val Acc: 0.9199
# [Step 24000] Val Loss: 0.3095 Val Acc: 0.9241
# Epoch [13/20]  Train Loss: 0.0736  Train Acc: 0.9730
# [Step 24500] Val Loss: 0.3451 Val Acc: 0.9223
# [Step 25000] Val Loss: 0.3438 Val Acc: 0.9211
# [Step 25500] Val Loss: 0.3409 Val Acc: 0.9170
# [Step 26000] Val Loss: 0.3348 Val Acc: 0.9238
# Epoch [14/20]  Train Loss: 0.0716  Train Acc: 0.9742
# [Step 26500] Val Loss: 0.4143 Val Acc: 0.9234
# [Step 27000] Val Loss: 0.3365 Val Acc: 0.9177
# [Step 27500] Val Loss: 0.3629 Val Acc: 0.9183
# [Step 28000] Val Loss: 0.3563 Val Acc: 0.9175
# Epoch [15/20]  Train Loss: 0.0710  Train Acc: 0.9746
# [Step 28500] Val Loss: 0.3790 Val Acc: 0.9214
# [Step 29000] Val Loss: 0.3683 Val Acc: 0.9257
# [Step 29500] Val Loss: 0.3526 Val Acc: 0.9198
# [Step 30000] Val Loss: 0.3836 Val Acc: 0.9193
# Epoch [16/20]  Train Loss: 0.0632  Train Acc: 0.9767
# [Step 30500] Val Loss: 0.3807 Val Acc: 0.9223
# [Step 31000] Val Loss: 0.4686 Val Acc: 0.9172
# [Step 31500] Val Loss: 0.3779 Val Acc: 0.9216
# Epoch [17/20]  Train Loss: 0.0638  Train Acc: 0.9778
# [Step 32000] Val Loss: 0.3914 Val Acc: 0.9223
# [Step 32500] Val Loss: 0.4412 Val Acc: 0.9163
# [Step 33000] Val Loss: 0.4240 Val Acc: 0.9188
# [Step 33500] Val Loss: 0.4044 Val Acc: 0.9182
# Epoch [18/20]  Train Loss: 0.0594  Train Acc: 0.9785
# [Step 34000] Val Loss: 0.4378 Val Acc: 0.9232
# [Step 34500] Val Loss: 0.4063 Val Acc: 0.9186
# [Step 35000] Val Loss: 0.3955 Val Acc: 0.9214
# [Step 35500] Val Loss: 0.4184 Val Acc: 0.9203
# Epoch [19/20]  Train Loss: 0.0601  Train Acc: 0.9791
# [Step 36000] Val Loss: 0.4373 Val Acc: 0.9210
# [Step 36500] Val Loss: 0.3955 Val Acc: 0.9187
# [Step 37000] Val Loss: 0.4381 Val Acc: 0.9176
# [Step 37500] Val Loss: 0.3680 Val Acc: 0.9226
# Epoch [20/20]  Train Loss: 0.0583  Train Acc: 0.9802

# %%
trainer.plot_curves()
